# %% [markdown]
# # 1. Import Python modules :-

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # 2. Load and display the dataset :-

# %%
df = pd.read_csv("Doctor-Visit-Analysis.csv")
df.head(15)
# Out:
#     SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0       1  8/20/2023          236781        6722  Female   37           0.55
# 1       2   7/1/2023          236782        7587  Female   62           0.45
# 2       3  7/28/2023          236783        2640    Male   64           0.90
# 3       4  7/27/2023          236784        9538    Male   35           0.15
# 4       5   7/2/2023          236785        5612    Male   30           0.45
# 5       6  7/14/2023          236786        5438  Female   36           0.35
# 6       7   7/1/2023          236787        7952  Female   46           0.55
# 7       8  7/15/2023          236788        3349  Female   54           0.15
# 8       9  8/23/2023          236789        7868  Female   23           0.65
# 9      10   7/8/2023          236790        9283    Male   65           0.15
# 10     11   7/6/2023          236791        9341    Male   40           0.45
# ...

# %% [markdown]
# # 3. Display complete dataset using EDA (Exploratory Data Analysis) :-

# %%
print(df.head(15))
# Out:
#     SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0       1  8/20/2023          236781        6722  Female   37           0.55
# 1       2   7/1/2023          236782        7587  Female   62           0.45
# 2       3  7/28/2023          236783        2640    Male   64           0.90
# 3       4  7/27/2023          236784        9538    Male   35           0.15
# 4       5   7/2/2023          236785        5612    Male   30           0.45
# 5       6  7/14/2023          236786        5438  Female   36           0.35
# 6       7   7/1/2023          236787        7952  Female   46           0.55
# 7       8  7/15/2023          236788        3349  Female   54           0.15
# 8       9  8/23/2023          236789        7868  Female   23           0.65
# 9      10   7/8/2023          236790        9283    Male   65           0.15
# 10     11   7/6/2023          236791        9341    Male   40           0.45
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SI.NO                 1000 non-null   int64
#  1   Date                  1000 non-null   object
#  2   Appointment ID        1000 non-null   int64
#  3   Patient ID            1000 non-null   int64
#  4   Gender                1000 non-null   object
#  5   Age                   1000 non-null   int64
#  6   Salary_Income         1000 non-null   float64
#  7   Martial status        1000 non-null   object
#  8   Appointment Reason    1000 non-null   object
#  9   Illness               1000 non-null   int64
#  10  Blood Pressure        1000 non-null   object
#  11  Diabetes              1000 non-null   bool
#  12  Reduced               1000 non-null   int64
#  13  Health                1000 non-null   int64
#  14  Private               1000 non-null   object
# ...

# %%
print(df.describe())
# Out:
#              SI.NO  Appointment ID   Patient ID          Age  Salary_Income  \
# count  1000.000000     1000.000000  1000.000000  1000.000000    1000.000000
# mean    500.500000   237280.500000  5521.846000    42.424000       0.535150
# std     288.819436      288.819436  2566.613827    12.802896       0.359991
# min       1.000000   236781.000000  1013.000000    21.000000       0.000000
# 25%     250.750000   237030.750000  3366.250000    31.000000       0.250000
# 50%     500.500000   237280.500000  5462.000000    42.000000       0.450000
# 75%     750.250000   237530.250000  7729.250000    54.000000       0.750000
# max    1000.000000   237780.000000  9999.000000    65.000000       1.500000
#
#            Illness      Reduced       Health  Height (cm)  Weight (kgs)  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean      2.179000     2.637000     2.030000   155.526000     72.368000
# ...

# %%
print(df['Patient ID'].value_counts())
# Out:
# 5934    3
# 6143    3
# 7472    2
# 3263    2
# 1163    2
#        ..
# 9870    1
# 2332    1
# 9196    1
# 2895    1
# 3192    1
# Name: Patient ID, Length: 948, dtype: int64

# %% [markdown]
# # 4. Data Visualization :-

# %%
plt.hist(df['Height (cm)'],bins=12, edgecolor='black')
plt.xlabel('Height(cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Patient Height with Frequency')
plt.show()

# %%
sns.histplot(data=df, x='Age', bins=10)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Patient Age with count')
plt.show()

# %%
sns.histplot(data=df, x='Weight (kgs)', bins=8)
plt.xlabel('Weight (kgs)')
plt.ylabel('Count')
plt.title('Distribution of Patient weight with count')
plt.show()

# %%
sns.scatterplot(data=df, x='Visit Duration', y='Wait time (mins)')
plt.xlabel('Visit Duration')
plt.ylabel('Wait time (mins)')
plt.title('Visit Duration vs. Wait time (mins)')
plt.show()

# %%
doctor_visits = df['Patient ID']
plt.bar(doctor_visits.index, doctor_visits.values)
plt.xlabel('Counts')
plt.ylabel('Patient ID')
plt.title('Patient ID Counts')
plt.show()

# %%
doctor_visits = df['Appointment ID']
plt.bar(doctor_visits.index, doctor_visits.values)
plt.xlabel('Counts')
plt.ylabel('Appointment ID')
plt.title('Appointment ID Counts')
plt.show()

# %%
doctor_visits = df['Visits']
plt.bar(doctor_visits.index, doctor_visits.values)
plt.xlabel('Counts')
plt.ylabel('Visits')
plt.title('Patient Visit Counts')
plt.show()

# %%
sns.histplot(data=df, x='Age', y='Height (cm)', bins=5)
plt.xlabel('Age')
plt.ylabel('Height')
plt.title('Distribution of Patient Ages with Height')
plt.show()

# %% [markdown]
# # 5. Data Cleaning :-

# %%
data = df.dropna()
print("Data:\n",data)
# Out:
# Data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1  8/20/2023          236781        6722  Female   37           0.55
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 2        3  7/28/2023          236783        2640    Male   64           0.90
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 4        5   7/2/2023          236785        5612    Male   30           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996   8/4/2023          237776        5413    Male   42           0.25
# 996    997  7/18/2023          237777        9266  Female   42           0.35
# 997    998  8/30/2023          237778        5463    Male   55           0.25
# 998    999   8/3/2023          237779        9219    Male   41           0.25
# 999   1000  7/22/2023          237780        3192  Female   48           0.35
#
# ...

# %%
data= df.drop_duplicates()
print("Data:\n",data)
# Out:
# Data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1  8/20/2023          236781        6722  Female   37           0.55
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 2        3  7/28/2023          236783        2640    Male   64           0.90
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 4        5   7/2/2023          236785        5612    Male   30           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996   8/4/2023          237776        5413    Male   42           0.25
# 996    997  7/18/2023          237777        9266  Female   42           0.35
# 997    998  8/30/2023          237778        5463    Male   55           0.25
# 998    999   8/3/2023          237779        9219    Male   41           0.25
# 999   1000  7/22/2023          237780        3192  Female   48           0.35
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
print("Data:\n",df)
# Out:
# Data:
#      SI.NO       Date  Doctor ID  Appointment ID  Patient ID  Gender  Age  \
# 0       1 2023-06-07        101          236781        1323  Female   24
# 1       2 2023-06-07        102          236782        2342  Female   26
# 2       3 2023-06-07        103          236783        4323    Male   32
# 3       4 2023-06-07        104          236784        3244    Male   24
# 4       5 2023-06-07        105          236785        3453    Male   33
# 5       6 2023-06-07        106          236786        3654  Female   27
# 6       7 2023-06-08        107          236787        4674  Female   25
# 7       8 2023-06-08        108          236788        1211  Female   29
# 8       9 2023-06-08        109          236789        1009  Female   35
# 9      10 2023-06-08        110          236790         990    Male   34
# 10     11 2023-06-09        111          236791        1122    Male   37
# 11     12 2023-06-09        112          236792        1311  Female   33
# ...

# %% [markdown]
# # 6. Statistical Analysis :-

# %%
average_age = np.mean(df['Age'])
print("Average Age:", average_age)
# Out:
# Average Age: 42.424

# %%
correlation = df['Age'].corr(df['Visit Duration'])
print("Correlation:", correlation)
# Out:
# Correlation: -0.024077207195303162

# %% [markdown]
# # 7. Descriptive Statistics :-

# %%
summary_stats = df.describe()
print("Summary stats :\n",summary_stats)
# Out:
# Summary stats :
#               SI.NO  Appointment ID   Patient ID          Age  Salary_Income  \
# count  1000.000000     1000.000000  1000.000000  1000.000000    1000.000000
# mean    500.500000   237280.500000  5521.846000    42.424000       0.535150
# std     288.819436      288.819436  2566.613827    12.802896       0.359991
# min       1.000000   236781.000000  1013.000000    21.000000       0.000000
# 25%     250.750000   237030.750000  3366.250000    31.000000       0.250000
# 50%     500.500000   237280.500000  5462.000000    42.000000       0.450000
# 75%     750.250000   237530.250000  7729.250000    54.000000       0.750000
# max    1000.000000   237780.000000  9999.000000    65.000000       1.500000
#
#            Illness      Reduced       Health  Height (cm)  Weight (kgs)  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean      2.179000     2.637000     2.030000   155.526000     72.368000
# ...

# %%
gender_count = df['Gender'].value_counts()
print("Gender counts:\n",gender_count)
# Out:
# Gender counts:
#  Female    512
# Male      488
# Name: Gender, dtype: int64

# %% [markdown]
# # 8. Filtering Data :-

# %%
female_patients = df[df['Gender'] == 'Female']
print("Female patients:\n",female_patients)
# Out:
# Female patients:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1  8/20/2023          236781        6722  Female   37           0.55
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 5        6  7/14/2023          236786        5438  Female   36           0.35
# 6        7   7/1/2023          236787        7952  Female   46           0.55
# 7        8  7/15/2023          236788        3349  Female   54           0.15
# ..     ...        ...             ...         ...     ...  ...            ...
# 992    993  7/17/2023          237773        4341  Female   34           0.35
# 993    994   8/4/2023          237774        5689  Female   31           0.35
# 994    995  8/21/2023          237775        5998  Female   46           0.90
# 996    997  7/18/2023          237777        9266  Female   42           0.35
# 999   1000  7/22/2023          237780        3192  Female   48           0.35
#
# ...

# %%
male_patients = df[df['Gender'] == 'Male']
print("Male patients:\n",male_patients)
# Out:
# Male patients:
#      SI.NO       Date  Doctor ID  Appointment ID  Patient ID Gender  Age  \
# 2       3 2023-06-07        103          236783        4323   Male   32
# 3       4 2023-06-07        104          236784        3244   Male   24
# 4       5 2023-06-07        105          236785        3453   Male   33
# 9      10 2023-06-08        110          236790         990   Male   34
# 10     11 2023-06-09        111          236791        1122   Male   37
#
#     Salary_Income Martial status Appointment Reason  ...  Weight (kgs)  \
# 2            0.90        Married          Follow up  ...            87
# 3            0.15    Not married           Check up  ...            54
# 4            0.45        Married          Follow up  ...            56
# 9            0.15        Married           Check up  ...            51
# 10           0.45        Married          Follow up  ...            59
#
#       Diagnosis  Smoking Status  Alcohol Consumption  Wait time (mins)  \
# ...

# %%
regular_checkup_patients = df[(df['Appointment Reason'] == 'Check up') & (df['Age'] >= 30)]
print("Regular check up patients:\n",regular_checkup_patients)
# Out:
# Regular check up patients:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 5        6  7/14/2023          236786        5438  Female   36           0.35
# 6        7   7/1/2023          236787        7952  Female   46           0.55
# 9       10   7/8/2023          236790        9283    Male   65           0.15
# ..     ...        ...             ...         ...     ...  ...            ...
# 993    994   8/4/2023          237774        5689  Female   31           0.35
# 996    997  7/18/2023          237777        9266  Female   42           0.35
# 997    998  8/30/2023          237778        5463    Male   55           0.25
# 998    999   8/3/2023          237779        9219    Male   41           0.25
# 999   1000  7/22/2023          237780        3192  Female   48           0.35
#
# ...

# %%
regular_checkup_patients = df[(df['Appointment Reason'] == 'Follow up') & (df['Age'] >= 30)]
print("Regular follow up patients:\n",regular_checkup_patients)
# Out:
# Regular follow up patients:
#      SI.NO       Date  Doctor ID  Appointment ID  Patient ID  Gender  Age  \
# 2       3 2023-06-07        103          236783        4323    Male   32
# 4       5 2023-06-07        105          236785        3453    Male   33
# 10     11 2023-06-09        111          236791        1122    Male   37
# 13     14 2023-06-09        114          236794        1212  Female   32
# 14     15 2023-06-09        115          236795        1223  Female   31
#
#     Salary_Income Martial status Appointment Reason  ...  Weight (kgs)  \
# 2            0.90        Married          Follow up  ...            87
# 4            0.45        Married          Follow up  ...            56
# 10           0.45        Married          Follow up  ...            59
# 13           0.45    Not married          Follow up  ...            77
# 14           0.25        Married          Follow up  ...            87
#
# ...

# %%
regular_checkup_patients = df[(df['Appointment Reason'] == 'Check up') & (df['Age'] <= 30)]
print("Regular check up patients:\n",regular_checkup_patients)
# Out:
# Regular check up patients:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 8        9  8/23/2023          236789        7868  Female   23           0.65
# 43      44   8/3/2023          236824        7747  Female   27           0.55
# 57      58  8/22/2023          236838        9570  Female   29           0.45
# 66      67   8/1/2023          236847        1190    Male   29           0.55
# 72      73  8/24/2023          236853        5725    Male   30           0.25
# ..     ...        ...             ...         ...     ...  ...            ...
# 948    949  7/15/2023          237729        4758    Male   27           0.25
# 952    953  7/18/2023          237733        8054  Female   21           0.25
# 965    966  7/13/2023          237746        9340  Female   26           0.55
# 972    973   7/7/2023          237753        7145    Male   22           0.25
# 991    992  8/27/2023          237772        1471  Female   23           0.25
#
# ...

# %%
regular_checkup_patients = df[(df['Appointment Reason'] == 'Follow up') & (df['Age'] <= 30)]
print("Regular follow up patients:\n",regular_checkup_patients)
# Out:
# Regular follow up patients:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 4        5   7/2/2023          236785        5612    Male   30           0.45
# 18      19  8/14/2023          236799        2273    Male   23           0.45
# 45      46  7/14/2023          236826        7038    Male   29           0.25
# 53      54  7/31/2023          236834        3048    Male   29           0.35
# 83      84  7/25/2023          236864        2245  Female   25           0.35
# ..     ...        ...             ...         ...     ...  ...            ...
# 950    951  8/10/2023          237731        2703  Female   28           0.25
# 960    961   7/4/2023          237741        5579  Female   24           0.45
# 971    972  7/20/2023          237752        1698  Female   24           0.25
# 973    974   7/5/2023          237754        5254    Male   25           0.25
# 988    989  7/12/2023          237769        5934  Female   28           0.90
#
# ...

# %% [markdown]
# # 9. Grouping and aggregating data :-

# %%
average_age_by_gender = df.groupby('Gender')['Age'].mean()
print("Average age by gender:\n",average_age_by_gender)
# Out:
# Average age by gender:
#  Gender
# Female    42.904297
# Male      41.920082
# Name: Age, dtype: float64

# %%
total_duration_by_appointment_type = df.groupby('Appointment Reason')['Visit Duration'].sum()
print("Total duration by appointment:\n",total_duration_by_appointment_type)
# Out:
# Total duration by appointment:
#  Appointment Reason
# Check up     15385
# Follow up    14662
# Name: Visit Duration, dtype: int64

# %% [markdown]
# # 10. Sorting Data :-

# %%
sorted_df = df.sort_values('Age', ascending=False)
print("Sorted DF:\n",sorted_df)
# Out:
# Sorted DF:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 385    386  7/27/2023          237166        9573    Male   65           0.75
# 591    592  8/22/2023          237372        2220    Male   65           0.90
# 114    115  8/11/2023          236895        6325  Female   65           0.00
# 767    768  7/24/2023          237548        7814    Male   65           0.25
# 829    830   7/2/2023          237610        1611    Male   65           0.25
# ..     ...        ...             ...         ...     ...  ...            ...
# 130    131  8/24/2023          236911        9306    Male   21           0.55
# 544    545   8/3/2023          237325        9405  Female   21           0.25
# 952    953  7/18/2023          237733        8054  Female   21           0.25
# 86      87  8/29/2023          236867        2760    Male   21           0.35
# 612    613   8/9/2023          237393        8966  Female   21           0.25
#
# ...

# %%
sorted_df = df.sort_values('Age', ascending=True)
print("Sorted DF:\n",sorted_df)
# Out:
# Sorted DF:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 86      87  8/29/2023          236867        2760    Male   21           0.35
# 150    151  7/19/2023          236931        2824    Male   21           0.65
# 130    131  8/24/2023          236911        9306    Male   21           0.55
# 621    622  7/17/2023          237402        4911  Female   21           0.25
# 612    613   8/9/2023          237393        8966  Female   21           0.25
# ..     ...        ...             ...         ...     ...  ...            ...
# 530    531  7/13/2023          237311        1594  Female   65           0.25
# 274    275   7/1/2023          237055        1980  Female   65           0.90
# 358    359  7/27/2023          237139        8348    Male   65           0.90
# 915    916  8/18/2023          237696        3852  Female   65           0.25
# 47      48  8/29/2023          236828        7721    Male   65           0.25
#
# ...

# %% [markdown]
# # 11. Visualization of dataset :-

# %%
gender_count.plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Number of Patients by Gender')
plt.show()

# %%
df.boxplot(column='Visit Duration', by='Appointment Reason')
plt.xlabel('Appointment Reason')
plt.ylabel('Visit Duration')
plt.title('Visit Duration by Appointment Type')
plt.show()

# %% [markdown]
# # 12. Data Aggregation :-

# %%
average_duration_by_diagnosis = df.groupby('Diagnosis')['Visit Duration'].mean()
print("Average duration by diagnosis:\n",average_duration_by_diagnosis)
# Out:
# Average duration by diagnosis:
#  Diagnosis
# Acute Myocardial Infarction      32.000000
# Allergic Rhinitis                30.416667
# Allergies                        29.333333
# Anemia                           26.181818
# Anxiety Disorder                 26.000000
#                                    ...
# Stroke                           29.545455
# Urinary Incontinence             32.181818
# Urinary Stones                   27.250000
# Urinary Tract Infection          30.500000
# Urinary Tract Infection (UTI)    28.833333
# Name: Visit Duration, Length: 64, dtype: float64

# %%
max_bloodpressure_by_gender = df.groupby('Gender')['Blood Pressure'].max()
print("Max Blood pressure:\n",max_bloodpressure_by_gender)
# Out:
# Max Blood pressure:
#  Gender
# Female    140/90
# Male      140/90
# Name: Blood Pressure, dtype: object

# %%
max_height_by_gender = df.groupby('Gender')['Height (cm)'].max()
print("Max height:\n",max_height_by_gender)
# Out:
# Max height:
#  Gender
# Female    190
# Male      190
# Name: Height (cm), dtype: int64

# %%
max_weight_by_gender = df.groupby('Gender')['Weight (kgs)'].max()
print("Max weight:\n",max_weight_by_gender)
# Out:
# Max weight:
#  Gender
# Female     99
# Male      100
# Name: Weight (kgs), dtype: int64

# %% [markdown]
# # 13. Data Filtering with Multiple Conditions :-

# %%
middle_age_patients_with_allergies = df[(df['Diabetes'].notnull()) & (df['Age'] > 30)]
print("Middle age patient with allergies:\n",middle_age_patients_with_allergies)
# Out:
# Middle age patient with allergies:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1  8/20/2023          236781        6722  Female   37           0.55
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 2        3  7/28/2023          236783        2640    Male   64           0.90
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 5        6  7/14/2023          236786        5438  Female   36           0.35
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996   8/4/2023          237776        5413    Male   42           0.25
# 996    997  7/18/2023          237777        9266  Female   42           0.35
# 997    998  8/30/2023          237778        5463    Male   55           0.25
# 998    999   8/3/2023          237779        9219    Male   41           0.25
# ...

# %%
young_patients_with_allergies = df[(df['Diabetes'].notnull()) & (df['Age'] < 30)]
print("Young patient with allergies:\n",young_patients_with_allergies)
# Out:
# Young patient with allergies:
#     SI.NO      Date  Doctor ID  Appointment ID  Patient ID  Gender  Age  \
# 0      1  6/7/2023        101          236781        1323  Female   24
# 1      2  6/7/2023        102          236782        2342  Female   26
# 3      4  6/7/2023        104          236784        3244    Male   24
# 5      6  6/7/2023        106          236786        3654  Female   27
# 6      7  6/8/2023        107          236787        4674  Female   25
# 7      8  6/8/2023        108          236788        1211  Female   29
#
#    Salary_Income Martial status Appointment Reason  ...  Weight (kgs)  \
# 0           0.55        Married          Follow up  ...            65
# 1           0.45    Not married           Check up  ...            66
# 3           0.15    Not married           Check up  ...            54
# 5           0.35        Married           Check up  ...            87
# 6           0.55    Not married           Check up  ...            74
# ...

# %%
smokers_with_high_blood_pressure = df[(df['Smoking Status'] == 'Smoker') & (df['Alcohol Consumption']=='Regular')]
print("Smoker status and alcohol consumption with high blood pressure:\n",smokers_with_high_blood_pressure)
# Out:
# Smoker status and alcohol consumption with high blood pressure:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 7        8  7/15/2023          236788        3349  Female   54           0.15
# 12      13  7/16/2023          236793        7822  Female   43           0.55
# 14      15  7/26/2023          236795        5291  Female   61           0.25
# 18      19  8/14/2023          236799        2273    Male   23           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 983    984  7/14/2023          237764        5896    Male   39           0.25
# 986    987  8/27/2023          237767        2220  Female   49           0.25
# 991    992  8/27/2023          237772        1471  Female   23           0.25
# 994    995  8/21/2023          237775        5998  Female   46           0.90
# ...

# %%
smokers_with_high_blood_pressure = df[(df['Smoking Status'] == 'Smoker') & (df['Blood Pressure'] >= '130/85')]
print("Smoker with high blood pressure :\n",smokers_with_high_blood_pressure)
# Out:
# Smoker with high blood pressure :
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 1        2   7/1/2023          236782        7587  Female   62           0.45
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 7        8  7/15/2023          236788        3349  Female   54           0.15
# 12      13  7/16/2023          236793        7822  Female   43           0.55
# 16      17  7/23/2023          236797        7011  Female   51           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 987    988   8/7/2023          237768        5126  Female   59           0.25
# 991    992  8/27/2023          237772        1471  Female   23           0.25
# 993    994   8/4/2023          237774        5689  Female   31           0.35
# 994    995  8/21/2023          237775        5998  Female   46           0.90
# 997    998  8/30/2023          237778        5463    Male   55           0.25
# ...

# %%
alcohol_consumption_with_high_blood_pressure = df[(df['Alcohol Consumption'] == 'Regular') & (df['Blood Pressure'] >= '130/85')]
print("Alcohol consumption with high blood pressure :\n",alcohol_consumption_with_high_blood_pressure)
# Out:
# Alcohol consumption with high blood pressure :
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 3        4  7/27/2023          236784        9538    Male   35           0.15
# 4        5   7/2/2023          236785        5612    Male   30           0.45
# 7        8  7/15/2023          236788        3349  Female   54           0.15
# 10      11   7/6/2023          236791        9341    Male   40           0.45
# 12      13  7/16/2023          236793        7822  Female   43           0.55
# ..     ...        ...             ...         ...     ...  ...            ...
# 964    965   8/2/2023          237745        1635  Female   58           0.55
# 976    977   7/8/2023          237757        6610    Male   32           0.75
# 979    980   7/7/2023          237760        1511  Female   38           0.25
# 991    992  8/27/2023          237772        1471  Female   23           0.25
# ...

# %% [markdown]
# # 14. Value Counts :-

# %%
payment_counts = df['Payment Method'].value_counts()
print("Payment counts:\n",payment_counts)
# Out:
# Payment counts:
#  Cash           333
# Credit card    267
# Insurance      200
# Debit card     200
# Name: Payment Method, dtype: int64

# %%
diagnosis_counts = df['Diagnosis'].value_counts()
print("Diagnosis counts:\n", diagnosis_counts)
# Out:
# Diagnosis counts:
#  Gastroenteritis                 36
# Allergies                       36
# Headache                        36
# Diabetes                        36
# Hyperlipidemia                  36
#                                 ..
# Conjunctivitis                  11
# Otitis Media                    11
# Inflammatory Bowel Disease      11
# Acute Myocardial Infarction     11
# Hypertensive Heart Disease      11
# Name: Diagnosis, Length: 64, dtype: int64

# %% [markdown]
# # 15. Find out the Total No.of people based on their count of illness :-

# %%
df["Illness"].value_counts()
# Out:
# 1    314
# 2    255
# 3    166
# 4     98
# 5     93
# 0     74
# Name: Illness, dtype: int64

# %% [markdown]
# # 16. Visualize and analyze maximum, minimum and medium income :-

# %%
y = list(df.Salary_Income)
plt.boxplot(y)
plt.title("Income")
plt.show()

# %% [markdown]
# # 17. Find out the no of days of reduced activity of males and females due to illness :-

# %%
df.groupby(['Gender','Reduced']).mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10380\3144783571.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Gender','Reduced']).mean()
#                      SI.NO  Appointment ID   Patient ID        Age  \
# Gender Reduced
# Female 0        526.274691   237306.274691  5416.901235  42.682099
#        1        319.103448   237099.103448  5518.172414  41.413793
#        2        405.916667   237185.916667  5590.166667  41.291667
#        3        454.636364   237234.636364  4759.045455  45.454545
#        4        347.875000   237127.875000  5989.500000  42.437500
#        5        394.666667   237174.666667  4387.222222  40.555556
#        6        442.833333   237222.833333  6684.500000  41.000000
#        7        430.200000   237210.200000  5152.600000  47.000000
# ...

# %% [markdown]
# # 18.  Visualize is there any missing values in the dataset based on heat map :-

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # 19.  Find out the correlation between variables and different variables in the given dataset :-

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10380\1181432401.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %% [markdown]
# # 20. Analyse How the income of a patient that effects the no of visits to the Hospital :-

# %%
plt.figure(figsize=(15,15))
plt.scatter(x='Salary_Income',y='Visits',data=df)
plt.xlabel('Income')
plt.ylabel('Visits')
# Out:
# Text(0, 0.5, 'Visits')

# %% [markdown]
# # 21. Count and Visualize the no of males and females affected by illness :-

# %%
sns.histplot(df.Gender, bins=2)
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# # 22. Visualize the percentage of people getting govt health insurance due to low income, due to old age and also the percentage of people having private health insurance :-

# %%
label=['Yes', 'No']
Y = df[df['Freepoor']=='Yes']
N = df[df['Freepoor']=='No']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label)
plt.title("% of people getting govt health Insurance due to low income ")
plt.show()
Y = df[df['Private']=='Yes']
N = df[df['Private']=='No']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label)
plt.title("% of people having private health Insurance ")
plt.show()
Y = df[df['Freerepat']=='Yes'] 
N = df[df['Freerepat']=='No']
x = [Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label)
plt.title("% of people getting govt health Insurance due to old age, disability or veteran status")
plt.show()

# %% [markdown]
# # 23. Plot a horizontal bar chart to analyze the reduced days of activity due to illness based on gender :-

# %%
db= df.groupby('Gender')['Reduced'].sum().to_frame().reset_index()
plt.barh(db['Gender'], db['Reduced'], color = ['cornflowerblue', 'lightseagreen'])
plt.title('Bar Chart')
plt.xlabel('Reduced Activity')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# # 24. Bar Plot :-

# %%
appointment_type_counts = df['Appointment Reason'].value_counts()
plt.bar(appointment_type_counts.index, appointment_type_counts.values)
plt.xlabel('Appointment Reason')
plt.ylabel('Count')
plt.title('Number of Patients by Appointment Type')
plt.show()

# %% [markdown]
# # 25. Pie chart :-

# %%
gender_counts = df['Gender'].value_counts()
plt.pie(gender_counts.values, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution among Patients')
plt.show()

# %% [markdown]
# # 26. Line plot :-

# %%
df['Date'] = pd.to_datetime(df['Date'])
average_duration_by_date = df.groupby('Date')['Visit Duration'].mean()
plt.plot(average_duration_by_date.index, average_duration_by_date.values)
plt.xlabel('Date')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration over Time')
plt.show()

# %% [markdown]
# # 27. Heat map :-

# %%
numerical_columns = ['Age', 'Visit Duration', 'Weight (kgs)', 'Height (cm)']
correlation_matrix = df[numerical_columns].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %% [markdown]
# # 28. Blocks plot :-

# %%
numerical_columns = ['Age', 'Visit Duration', 'Weight (kgs)', 'Height (cm)']
correlation_matrix = df[numerical_columns].corr()
print("Correlation matrix:\n",correlation_matrix)
# Out:
# Correlation matrix:
#                       Age  Visit Duration  Weight (kgs)  Height (cm)
# Age             1.000000       -0.024077      0.036379     0.074922
# Visit Duration -0.024077        1.000000      0.039281    -0.015157
# Weight (kgs)    0.036379        0.039281      1.000000    -0.033550
# Height (cm)     0.074922       -0.015157     -0.033550     1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Variables')
plt.show()

# %%
gender_counts = df['Gender'].value_counts().reset_index()
gender_counts.columns = ['Gender', 'Count']
plt.barh(gender_counts['Gender'], gender_counts['Count'], color=['blue', 'pink'])
plt.xlabel('Count')
plt.ylabel('Gender')
plt.title('Number of Patients by Gender')
plt.show()

# %% [markdown]
# # 29. Stacked bar plot :-

# %%
gender_smoking_counts = df.groupby(['Gender','Smoking Status']).size().unstack()
gender_smoking_counts.plot(kind='bar', stacked=True)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Count of Patients by Gender and Smoking Status')
plt.legend(title='Smoking Status')
plt.show()

# %% [markdown]
# # 30. Scatter plot with regression line :-

# %%
sns.regplot(data=df, x='Age', y='Visit Duration')
plt.xlabel('Age')
plt.ylabel('Visit Duration')
plt.title('Age vs. Visit Duration')
plt.show()

# %% [markdown]
# # 31. Pair Plot :-

# %%
sns.pairplot(data=df,vars=['Age', 'Visit Duration', 'Weight (kgs)', 'Height (cm)'])
plt.show()

# %% [markdown]
# # 32. Area plot :-

# %%
df['cumulative_duration'] = df['Visit Duration'].cumsum()
plt.fill_between(df['Date'], df['cumulative_duration'])
plt.xlabel('Date')
plt.ylabel('Cumulative Visit Duration')
plt.title('Cumulative Visit Duration over Time')
plt.show()

# %% [markdown]
# # 33. Boxen plot :-

# %%
sns.boxenplot(data=df, x='Gender', y='Visit Duration')
plt.xlabel('Gender')
plt.ylabel('Visit Duration')
plt.title('Distribution of Visit Durations by Gender')
plt.show()

# %% [markdown]
# # 34. KDE plot :-

# %%
sns.kdeplot(data=df, x='Visit Duration')
plt.xlabel('Visit Duration')
plt.ylabel('Wait time (mins)')
plt.title('Distribution of Visit Durations')
plt.show()

# %% [markdown]
# # 35. Line plot with multiple lines :-

# %%
average_duration_by_type = df.groupby(['Date', 'Appointment Reason'])['Visit Duration'].mean().unstack()
average_duration_by_type.plot()
plt.xlabel('Date')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration over Time by Appointment Type')
plt.legend(title='Appointment Type')
plt.show()

# %% [markdown]
# # 36. Donut plot :-

# %%
appointment_type_counts = df['Appointment Reason'].value_counts()
plt.pie(appointment_type_counts.values, labels=appointment_type_counts.index,
        wedgeprops={'edgecolor': 'white'}, autopct='%1.1f%%')
circle = plt.Circle((0, 0), 0.4, color='white')
plt.gca().add_artist(circle)
plt.title('Distribution of Appointment Reason')
plt.show()

# %% [markdown]
# # 37. Lollipop plot :-

# %%
average_duration_by_occupation = df.groupby('Diagnosis')['Visit Duration'].mean().sort_values(ascending=False)
plt.stem(average_duration_by_occupation.index, average_duration_by_occupation.values, basefmt=' ')
plt.xlabel('Diagnosis')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration by Diagnosis')
plt.xticks(rotation=45)
plt.show()

# %%
average_duration_by_occupation = df.groupby('Diagnosis')['Visit Duration'].mean().sort_values(ascending=True)
plt.stem(average_duration_by_occupation.index, average_duration_by_occupation.values, basefmt=' ')
plt.xlabel('Diagnosis')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration by Diagnosis')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 38. Bar plot with error bars :-

# %%
average_duration_by_diagnosis = df.groupby('Diagnosis')['Visit Duration'].mean()
std_duration_by_diagnosis = df.groupby('Diagnosis')['Visit Duration'].std()
plt.bar(average_duration_by_diagnosis.index, average_duration_by_diagnosis.values,
        yerr=std_duration_by_diagnosis.values, capsize=5)
plt.xlabel('Diagnosis')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration by Diagnosis')
plt.show()

# %% [markdown]
# # 39. Histogram :-

# %%
df['Age'].hist()
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age count')
plt.show()

# %%
df['Gender'].hist()
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender count')
plt.show()

# %% [markdown]
# # 40. Step plot :-

# %%
df['Cumulative Duration'] = df['Visit Duration'].cumsum()
plt.step(df['Date'], df['Cumulative Duration'])
plt.xlabel('Date')
plt.ylabel('Cumulative Visit Duration')
plt.title('Cumulative Visit Duration over Time')
plt.show()

# %% [markdown]
# # 41. Line plot with multiple lines and shaded the area :-

# %%
average_duration_by_date_gender = df.groupby(['Date', 'Gender'])['Visit Duration'].mean().unstack()
std_duration_by_date_gender = df.groupby(['Date', 'Gender'])['Visit Duration'].std().unstack()
average_duration_by_date_gender.plot()
plt.fill_between(average_duration_by_date_gender.index, average_duration_by_date_gender['Female'] - std_duration_by_date_gender['Female'],
                 average_duration_by_date_gender['Female'] + std_duration_by_date_gender['Female'], alpha=0.3)
plt.fill_between(average_duration_by_date_gender.index, average_duration_by_date_gender['Male'] - std_duration_by_date_gender['Male'],
                 average_duration_by_date_gender['Male'] + std_duration_by_date_gender['Male'], alpha=0.3)
plt.xlabel('Date')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration over Time by Gender')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# # 42. Data Summary :-

# %%
first_few_rows = df.head()
print("First few rows:\n",first_few_rows)
# Out:
# First few rows:
#     SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0      1 2023-08-20          236781        6722  Female   37           0.55
# 1      2 2023-07-01          236782        7587  Female   62           0.45
# 2      3 2023-07-28          236783        2640    Male   64           0.90
# 3      4 2023-07-27          236784        9538    Male   35           0.15
# 4      5 2023-07-02          236785        5612    Male   30           0.45
#
#   Martial status Appointment Reason  Illness  ... Smoking Status  \
# 0        Married          Follow up        1  ...     Non-smoker
# 1    Not married           Check up        1  ...         Smoker
# 2        Married          Follow up        3  ...     Non-smoker
# 3    Not married           Check up        1  ...         Smoker
# 4        Married          Follow up        2  ...     Non-smoker
#
#    Alcohol Consumption  Wait time (mins)  Visit Duration Payment Method  \
# ...

# %%
summary_stats = df.describe()
print("Summary stats:\n",summary_stats)
# Out:
# Summary stats:
#             SI.NO   Doctor ID  Appointment ID   Patient ID        Age  \
# count  15.000000   15.000000       15.000000    15.000000  15.000000
# mean    8.000000  108.000000   236788.000000  2294.866667  30.333333
# std     4.472136    4.472136        4.472136  1338.479087   4.203173
# min     1.000000  101.000000   236781.000000   990.000000  24.000000
# 25%     4.500000  104.500000   236784.500000  1211.500000  26.500000
# 50%     8.000000  108.000000   236788.000000  1323.000000  32.000000
# 75%    11.500000  111.500000   236791.500000  3392.500000  33.000000
# max    15.000000  115.000000   236795.000000  4674.000000  37.000000
#
#        Salary_Income    Illness    Reduced     Health  Height (cm)  \
# count      15.000000  15.000000  15.000000  15.000000    15.000000
# mean        0.420000   2.400000   2.200000   2.266667   158.800000
# std         0.210272   1.298351   3.707136   2.840188    12.502571
# ...

# %%
data_types = df.dtypes
print("Data types:\n",data_types)
# Out:
# Data types:
#  SI.NO                            int64
# Date                    datetime64[ns]
# Appointment ID                   int64
# Patient ID                       int64
# Gender                          object
# Age                              int64
# Salary_Income                  float64
# Martial status                  object
# Appointment Reason              object
# Illness                          int64
# Blood Pressure                  object
# Diabetes                          bool
# Reduced                          int64
# Health                           int64
# Private                         object
# Freepoor                        object
# Freerepat                       object
# Nchronic                        object
# Ichronicc                       object
# Height (cm)                      int64
# Weight (kgs)                     int64
# Diagnosis                       object
# Smoking Status                  object
# Alcohol Consumption             object
# ...

# %% [markdown]
# # 43. Data filtering and selection :-

# %%
specific_doctor_visits=df['Date']
print("Specific doctor visits:\n",specific_doctor_visits)
# Out:
# Specific doctor visits:
#  0     2023-08-20
# 1     2023-07-01
# 2     2023-07-28
# 3     2023-07-27
# 4     2023-07-02
#          ...
# 995   2023-08-04
# 996   2023-07-18
# 997   2023-08-30
# 998   2023-08-03
# 999   2023-07-22
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
selected_columns = df[['Patient ID', 'Date', 'Diagnosis']]
print("Selected columns:\n",selected_columns)
# Out:
# Selected columns:
#       Patient ID       Date               Diagnosis
# 0          6722 2023-08-20            Hypertension
# 1          7587 2023-07-01                Diabetes
# 2          2640 2023-07-28             Common cold
# 3          9538 2023-07-27               Arthritis
# 4          5612 2023-07-02               Allergies
# ..          ...        ...                     ...
# 995        5413 2023-08-04         Hyperthyroidism
# 996        9266 2023-07-18         Urinary Stones
# 997        5463 2023-08-30                    Gout
# 998        9219 2023-08-03  Chronic Kidney Disease
# 999        3192 2023-07-22            Appendicitis
#
# [1000 rows x 3 columns]

# %% [markdown]
# # 44. Data Grouping and Aggregation :-

# %%
average_duration_by_gender = df.groupby('Gender')['Visit Duration'].mean()
print("Average Duration by Gender:\n",average_duration_by_gender)
# Out:
# Average Duration by Gender:
#  Gender
# Female    30.095703
# Male      29.995902
# Name: Visit Duration, dtype: float64

# %%
max_age_by_appointment_type = df.groupby('Appointment Reason')['Age'].max()
print("Max age by appointment:\n",max_age_by_appointment_type)
# Out:
# Max age by appointment:
#  Appointment Reason
# Check up     65
# Follow up    65
# Name: Age, dtype: int64

# %% [markdown]
# # 45. Data cleaning and preprocessing :-

# %%
missing_values = df.isnull().sum()
print("Missing values:\n",missing_values)
# Out:
# Missing values:
#  SI.NO                   0
# Date                    0
# Appointment ID          0
# Patient ID              0
# Gender                  0
# Age                     0
# Salary_Income           0
# Martial status          0
# Appointment Reason      0
# Illness                 0
# Blood Pressure          0
# Diabetes                0
# Reduced                 0
# Health                  0
# Private                 0
# Freepoor                0
# Freerepat               0
# Nchronic                0
# Ichronicc               0
# Height (cm)             0
# Weight (kgs)            0
# Diagnosis               0
# Smoking Status          0
# Alcohol Consumption     0
# Wait time (mins)        0
# Visit Duration          0
# Payment Method          0
# Insurance coverage      0
# Visits                  0
# Satisfication rating    0
# cumulative_duration     0
# Cumulative Duration     0
# dtype: int64

# %%
cleaned_data = df.dropna()
print("Cleaned data:\n",cleaned_data)
# Out:
# Cleaned data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1 2023-08-20          236781        6722  Female   37           0.55
# 1        2 2023-07-01          236782        7587  Female   62           0.45
# 2        3 2023-07-28          236783        2640    Male   64           0.90
# 3        4 2023-07-27          236784        9538    Male   35           0.15
# 4        5 2023-07-02          236785        5612    Male   30           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996 2023-08-04          237776        5413    Male   42           0.25
# 996    997 2023-07-18          237777        9266  Female   42           0.35
# 997    998 2023-08-30          237778        5463    Male   55           0.25
# 998    999 2023-08-03          237779        9219    Male   41           0.25
# 999   1000 2023-07-22          237780        3192  Female   48           0.35
#
# ...

# %% [markdown]
# # 46. Data sampling :-

# %%
sampled_data = df.sample(n=10, random_state=30)
print("Sampled data:\n",sampled_data)
# Out:
# Sampled data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 923    924 2023-07-21          237704        4399    Male   32           0.35
# 921    922 2023-07-12          237702        5035  Female   25           0.25
# 516    517 2023-08-02          237297        6967    Male   26           0.75
# 87      88 2023-07-06          236868        8265    Male   45           0.65
# 879    880 2023-08-13          237660        3060    Male   61           0.25
# 463    464 2023-08-16          237244        9819    Male   31           1.10
# 112    113 2023-08-04          236893        3780  Female   41           0.65
# 297    298 2023-07-13          237078        2366    Male   26           1.10
# 417    418 2023-08-12          237198        3656    Male   41           0.25
# 658    659 2023-07-06          237439        8231  Female   58           0.25
#
#     Martial status Appointment Reason  Illness  ... Smoking Status  \
# ...

# %%
fractional_sampled_data = df.sample(frac=0.3, random_state=42)
print("fractional sampled data:\n",fractional_sampled_data)
# Out:
# fractional sampled data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 521    522 2023-08-28          237302        3410    Male   36           0.75
# 737    738 2023-07-13          237518        4699    Male   65           0.25
# 740    741 2023-08-26          237521        4476  Female   51           0.35
# 660    661 2023-07-09          237441        1013    Male   43           1.10
# 411    412 2023-07-03          237192        7725  Female   38           1.50
# ..     ...        ...             ...         ...     ...  ...            ...
# 468    469 2023-07-06          237249        8325    Male   27           0.15
# 935    936 2023-07-10          237716        1997    Male   23           0.15
# 428    429 2023-08-29          237209        3043    Male   21           1.10
# 7        8 2023-07-15          236788        3349  Female   54           0.15
# 155    156 2023-08-09          236936        9205  Female   45           0.75
#
# ...

# %% [markdown]
# # 47. Data aggregation with custom function :-

# %%
total_duration_by_diagnosis = df.groupby('Diagnosis')['Visit Duration'].agg(lambda x: x.sum())
print("Total duration by diagnosis:\n",total_duration_by_diagnosis)
# Out:
# Total duration by diagnosis:
#  Diagnosis
# Acute Myocardial Infarction       352
# Allergic Rhinitis                 365
# Allergies                        1056
# Anemia                            288
# Anxiety Disorder                  312
#                                  ...
# Stroke                            325
# Urinary Incontinence              354
# Urinary Stones                    327
# Urinary Tract Infection           366
# Urinary Tract Infection (UTI)     346
# Name: Visit Duration, Length: 64, dtype: int64

# %%
median_age_by_appointment_type = df.groupby('Appointment Reason')['Age'].agg(lambda x: x.median())
print("Median age by appointment type:\n",median_age_by_appointment_type)
# Out:
# Median age by appointment type:
#  Appointment Reason
# Check up     42.0
# Follow up    42.0
# Name: Age, dtype: float64

# %% [markdown]
# # 48. Data reshaping and pivot tables :-

# %%
pivot_table = df.pivot_table(index='Gender', columns='Appointment Reason', values='Patient ID', aggfunc='count')
print("Pivot table:\n",pivot_table)
# Out:
# Pivot table:
#  Appointment Reason  Check up  Follow up
# Gender
# Female                   265        247
# Male                     246        242

# %%
pivot_table = df.pivot_table(index='Gender', columns='Diagnosis', values='Visit Duration', aggfunc='mean')
print("Pivot table:\n",pivot_table)
# Out:
# Pivot table:
#  Diagnosis  Acute Myocardial Infarction   Allergic Rhinitis  Allergies  Anemia  \
# Gender
# Female                            37.00          35.333333  28.842105    26.5
# Male                              23.25          25.500000  29.882353    25.8
#
# Diagnosis  Anxiety Disorder  Appendicitis  Arthritis     Asthma  \
# Gender
# Female            25.142857     26.833333       31.0  38.600000
# Male              27.200000     27.166667       21.0  26.857143
#
# Diagnosis  Benign Prostatic Hyperplasia  Bronchitis  ...  \
# Gender                                               ...
# Female                        31.000000   27.800000  ...
# Male                          26.142857   32.444444  ...
#
# Diagnosis  Polycystic Ovary Syndrome  Psoriasis  Pulmonary Embolism  \
# Gender
# Female                          33.0  31.600000           29.285714
# Male                            34.6  27.833333           36.250000
#
# ...

# %% [markdown]
# # 49. Data Sorting and Ranking :-

# %%
sorted_data = df.sort_values(by=['Age', 'Visit Duration'], ascending=[False, True])
print("Sorted data:\n",sorted_data)
# Out:
# Sorted data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 165    166 2023-07-24          236946        8537    Male   65           1.10
# 737    738 2023-07-13          237518        4699    Male   65           0.25
# 117    118 2023-07-10          236898        9157  Female   65           0.45
# 31      32 2023-07-26          236812        1099    Male   65           0.65
# 875    876 2023-08-10          237656        4736    Male   65           0.35
# ..     ...        ...             ...         ...     ...  ...            ...
# 425    426 2023-07-01          237206        9702  Female   21           1.10
# 544    545 2023-08-03          237325        9405  Female   21           0.25
# 840    841 2023-08-08          237621        4200  Female   21           0.25
# 130    131 2023-08-24          236911        9306    Male   21           0.55
# 428    429 2023-08-29          237209        3043    Male   21           1.10
#
# ...

# %%
sorted_data = df.sort_values(by=['Age', 'Visit Duration'], ascending=[True,False])
print("Sorted data:\n",sorted_data)
# Out:
# Sorted data:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 130    131 2023-08-24          236911        9306    Male   21           0.55
# 428    429 2023-08-29          237209        3043    Male   21           1.10
# 840    841 2023-08-08          237621        4200  Female   21           0.25
# 425    426 2023-07-01          237206        9702  Female   21           1.10
# 544    545 2023-08-03          237325        9405  Female   21           0.25
# ..     ...        ...             ...         ...     ...  ...            ...
# 875    876 2023-08-10          237656        4736    Male   65           0.35
# 31      32 2023-07-26          236812        1099    Male   65           0.65
# 117    118 2023-07-10          236898        9157  Female   65           0.45
# 165    166 2023-07-24          236946        8537    Male   65           1.10
# 737    738 2023-07-13          237518        4699    Male   65           0.25
#
# ...

# %%
df['Duration_rank'] = df.groupby('Diagnosis')['Visit Duration'].rank(ascending=False)
print("DF:\n",df)
# Out:
# DF:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1 2023-08-20          236781        6722  Female   37           0.55
# 1        2 2023-07-01          236782        7587  Female   62           0.45
# 2        3 2023-07-28          236783        2640    Male   64           0.90
# 3        4 2023-07-27          236784        9538    Male   35           0.15
# 4        5 2023-07-02          236785        5612    Male   30           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996 2023-08-04          237776        5413    Male   42           0.25
# 996    997 2023-07-18          237777        9266  Female   42           0.35
# 997    998 2023-08-30          237778        5463    Male   55           0.25
# 998    999 2023-08-03          237779        9219    Male   41           0.25
# 999   1000 2023-07-22          237780        3192  Female   48           0.35
#
# ...

# %%
df['Duration_rank'] = df.groupby('Diagnosis')['Visit Duration'].rank(ascending=True)
print("DF:\n",df)
# Out:
# DF:
#       SI.NO       Date  Appointment ID  Patient ID  Gender  Age  Salary_Income  \
# 0        1 2023-08-20          236781        6722  Female   37           0.55
# 1        2 2023-07-01          236782        7587  Female   62           0.45
# 2        3 2023-07-28          236783        2640    Male   64           0.90
# 3        4 2023-07-27          236784        9538    Male   35           0.15
# 4        5 2023-07-02          236785        5612    Male   30           0.45
# ..     ...        ...             ...         ...     ...  ...            ...
# 995    996 2023-08-04          237776        5413    Male   42           0.25
# 996    997 2023-07-18          237777        9266  Female   42           0.35
# 997    998 2023-08-30          237778        5463    Male   55           0.25
# 998    999 2023-08-03          237779        9219    Male   41           0.25
# 999   1000 2023-07-22          237780        3192  Female   48           0.35
#
# ...

# %% [markdown]
# # 50. Age grouping analysis :-

# %%
age_bins = [0, 18, 30, 40, 50, 60, 100]
age_labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '60+']
print(age_labels)
# Out:
# ['0-18', '19-30', '31-40', '41-50', '51-60', '60+']

# %%
average_visit_duration_by_age_group = df.groupby('Age')['Visit Duration'].mean()
count_by_age_group = df['Age'].value_counts()
print(count_by_age_group)
# Out:
# 56    33
# 28    29
# 31    29
# 32    29
# 54    29
# 30    28
# 42    28
# 25    28
# 23    27
# 62    27
# 35    26
# 38    25
# 48    24
# 46    24
# 44    24
# 50    23
# 57    23
# 27    23
# 33    23
# 52    23
# 55    22
# 49    22
# 40    22
# 47    22
# 65    22
# 37    22
# 29    21
# 41    21
# 24    21
# 53    21
# 43    21
# 51    20
# 61    20
# 21    20
# 59    20
# 34    20
# 36    18
# 22    18
# 58    18
# 39    16
# 26    16
# 64    16
# 60    15
# 63    11
# 45    10
# Name: Age, dtype: int64

# %%
plt.bar(average_visit_duration_by_age_group.index, average_visit_duration_by_age_group.values)
plt.xlabel('Age Group')
plt.ylabel('Average Visit Duration')
plt.title('Average Visit Duration by Age Group')
plt.show()

# %%
plt.bar(count_by_age_group.index, count_by_age_group.values)
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Number of Patients by Age Group')
plt.show()
